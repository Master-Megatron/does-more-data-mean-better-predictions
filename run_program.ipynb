# %%
# %time %run -i exercise_31_2_nomor_3_only.py
# Out:
# ...
# EXERCISE 3: Effect of Sample Size pada RMSE
# ...
#
# Processing n = 100...
#   Average RMSE: 2.6582
#   Std Dev RMSE: 0.2669
#
# Processing n = 500...
#   Average RMSE: 2.5975
#   Std Dev RMSE: 0.1243
#
# Processing n = 1000...
#   Average RMSE: 2.5932
#   Std Dev RMSE: 0.0852
#
# Processing n = 5000...
#   Average RMSE: 2.6010
#   Std Dev RMSE: 0.0376
#
# Processing n = 10000...
#   Average RMSE: 2.5991
#   Std Dev RMSE: 0.0247
#
# ...
# TABEL HASIL
# ...
#     n  avg_rmse  std_rmse
#   100  2.658236  0.266917
#   500  2.597489  0.124270
#  1000  2.593208  0.085232
#  5000  2.600999  0.037565
# 10000  2.599130  0.024709
#
#
# ...
# ANALISIS: Apa yang terjadi dengan RMSE?
# ...
#
# 1. AVERAGE RMSE:
#    n=100:    2.6582
#    n=10000:  2.5991
#    Change:   -2.22% ← HAMPIR TIDAK BERUBAH
#
# 2. STD DEV RMSE:
#    n=100:    0.2669
#    n=10000:  0.0247
#    Change:   -90.7% ← TURUN DRASTIS
# ✓ Plot saved: exercise3_analysis.png
#
#
# ...
# JAWABAN SOAL NOMOR 3
# ...
#
# PERTANYAAN:
# ...
